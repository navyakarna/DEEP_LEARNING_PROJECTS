# %% [markdown]
# <a href="https://colab.research.google.com/github/navyakarna/first-ml/blob/main/IMAGES_USING__SKIMAGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage
from skimage.io import imshow, imread, imsave
from skimage.transform import resize
import numpy as np

# %%
print('Skimage Version:' , skimage.__version__)
# Out:
# Skimage Version: 0.24.0

# %%
image_gray = imread('/content/pexels-minan1398-962312.jpg')

# %%
image_gray.shape
# Out:
# (2832, 4256, 3)

# %%
imshow(image_gray)

# %%
image = imread('/content/pexels-minan1398-962312.jpg')

# %%
image.shape
# Out:
# (2832, 4256, 3)

# %%
image
# Out:
# array([[[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        [[246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [246, 246, 246],
#         [246, 246, 246],
#         [246, 246, 246]],
#
#        ...,
#
#        [[ 14,  14,  14],
#         [  0,   0,   0],
#         [ 42,  42,  42],
#         ...,
#         [235, 235, 235],
#         [236, 236, 236],
#         [236, 236, 236]],
#
#        [[  0,   0,   0],
#         [ 21,  21,  21],
#         [126, 126, 126],
#         ...,
#         [235, 235, 235],
#         [236, 236, 236],
#         [236, 236, 236]],
#
#        [[ 14,  14,  14],
#         [  9,   9,   9],
#         [ 56,  56,  56],
# ...

# %%
imshow(image)

# %%
import numpy as np

#printing only red channel
red_filter = [1, 0, 0]
imshow(image*red_filter)
# Out:
# /usr/local/lib/python3.10/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
green_filter = [0,1,0]
imshow(image*green_filter)

# %%
blue_filter=[0,0,1]
imshow(image*blue_filter)

# %%
imshow(image[:,:,0], cmap='Reds')

# %%
RGBA = imread('/content/a corgi wearing a red santa hat.png')

# %%
RGBA.shape
# Out:
# (256, 256, 4)

# %%
RGBA[:,:,3]
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
RGBA[:,:,3] = RGBA[:,:,3]-180

# %%
imshow(RGBA)

# %%
import nibabel as nib

# %%
MRI= nib.load('/content/pexels-pixabay-220769.hdr')
MRI = MRI.get_data()

# %%
MRI.shape

# %%
import matplotlib.pyplot as plt

fig.ax =

# %%
from skimage.io import imshow, imread, imsave
from skimage.color import rgb2gray, rgba2rgb
import numpy as np

# %%
image = imread('/content/dog.jpg')

# %%
image.shape
# Out:
# (340, 453, 3)

# %%
imshow(image)

# %%
image_rgba = imread('/content/mid_alpha.png')

# %%
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
image_rgb = rgba2rgb(image_rgba)
image_rgb.shape
# Out:
# (340, 453, 3)

# %%
imshow(image_rgb)

# %%
image_rgba = imread('/content/mid_alpha.png')
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
image_rgb = rgba2rgb(image_rgba)
image_rgb.shape
# Out:
# (340, 453, 3)

# %%
imshow(image_rgb)

# %%
image_gray = rgb2gray(image_rgb)
image_gray.shape
# Out:
# (340, 453)

# %%
imshow(image_gray)

# %%
image = imread('dog.jpg', as_gray=True)
imshow(image)
